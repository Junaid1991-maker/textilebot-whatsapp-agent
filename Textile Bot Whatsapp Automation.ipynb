# %%
logger.info(f"Python version: {sys.version}")  # this produces output
logger.info(f"✓ anthropic {anthropic.__version__}")  # this produces output
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 logger.info(f"Python version: {sys.version}")  # this produces output
#       2 logger.info(f"✓ anthropic {anthropic.__version__}")  # this produces output
#
# NameError: name 'logger' is not defined
